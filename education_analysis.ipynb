# %%
# Capstone Project: Quality Education Analytics

This notebook performs data cleaning, exploratory data analysis (EDA), and clustering on Sustainable Development Goal 4 data related to quality education.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

sns.set(style="whitegrid")

# %%
# Load cleaned dataset
df = pd.read_csv("C:/Users/Hp/Desktop/27193 Final Project/education_data.csv")
df.head()
# Out:
#   STRUCTURE        STRUCTURE_ID  \
# 0  DATAFLOW  SPC:DF_SDG_04(3.0)
# 1  DATAFLOW  SPC:DF_SDG_04(3.0)
# 2  DATAFLOW  SPC:DF_SDG_04(3.0)
# 3  DATAFLOW  SPC:DF_SDG_04(3.0)
# 4  DATAFLOW  SPC:DF_SDG_04(3.0)
#
#                                       STRUCTURE_NAME ACTION FREQ Frequency  \
# 0  Sustainable Development Goal 04 - Quality Educ...      I    A    Annual
# 1  Sustainable Development Goal 04 - Quality Educ...      I    A    Annual
# 2  Sustainable Development Goal 04 - Quality Educ...      I    A    Annual
# 3  Sustainable Development Goal 04 - Quality Educ...      I    A    Annual
# 4  Sustainable Development Goal 04 - Quality Educ...      I    A    Annual
#
#       INDICATOR                                       Indicator GEO_PICT  \
# 0    SE_GC_TCAQ                          4.c.1 Trained teachers       WS
# 1    SE_GC_TCAQ                          4.c.1 Trained teachers       WS
# 2    SE_GC_TCAQ                          4.c.1 Trained teachers       WS
# 3  SE_PRE_PARTN  4.2.2 Participation rate in organised learning       PG
# 4  SE_PRE_PARTN  4.2.2 Participation rate in organised learning       PG
#
#   Pacific Island Countries and territories  ... REPORTING_TYPE Reporting type  \
# 0                                    Samoa  ...              G         Global
# 1                                    Samoa  ...              G         Global
# 2                                    Samoa  ...              G         Global
# 3                         Papua New Guinea  ...              G         Global
# 4                         Papua New Guinea  ...              G         Global
#
#   NATURE        Nature                      DATA_SOURCE Data source  \
# 0      C  Country Data   UNESCO Institute of Statistics         NaN
# 1      C  Country Data   UNESCO Institute of Statistics         NaN
# 2      C  Country Data   UNESCO Institute of Statistics         NaN
# 3      C  Country Data   UNESCO Institute of Statistics         NaN
# 4      C  Country Data  UNESCO Institute for Statistics         NaN
#
#   OBS_STATUS Observation Status OBS_COMMENT Comment
# 0        NaN                NaN         NaN     NaN
# 1        NaN                NaN         NaN     NaN
# 2        NaN                NaN         NaN     NaN
# 3        NaN                NaN         NaN     NaN
# 4        NaN                NaN         NaN     NaN
#
# [5 rows x 42 columns]

# %%
# Overview of data
print(df.info())
print(df.describe(include='all'))
print("Missing values:", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 42 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STRUCTURE                                 2095 non-null   object
#  1   STRUCTURE_ID                              2095 non-null   object
#  2   STRUCTURE_NAME                            2095 non-null   object
#  3   ACTION                                    2095 non-null   object
#  4   FREQ                                      2095 non-null   object
#  5   Frequency                                 2095 non-null   object
#  6   INDICATOR                                 2095 non-null   object
#  7   Indicator                                 2095 non-null   object
#  8   GEO_PICT                                  2095 non-null   object
#  9   Pacific Island Countries and territories  2095 non-null   object
#  10  SEX                                       2095 non-null   object
#  11  Sex                                       2095 non-null   object
#  12  AGE                                       2095 non-null   object
#  13  Age                                       2095 non-null   object
#  14  URBANIZATION                              2095 non-null   object
#  15  Urbanization                              2095 non-null   object
#  16  INCOME                                    2095 non-null   object
#  17  Income                                    2095 non-null   object
#  18  EDUCATION                                 2095 non-null   object
#  19  Education level                           2095 non-null   object
#  20  OCCUPATION                                2095 non-null   object
#  21  Occupation                                2095 non-null   object
#  22  COMPOSITE_BREAKDOWN                       2095 non-null   object
#  23  Composite breakdown                       2095 non-null   object
#  24  DISABILITY                                2095 non-null   object
#  25  Disability                                2095 non-null   object
#  26  TIME_PERIOD                               2095 non-null   int64
#  27  Time                                      0 non-null      float64
#  28  OBS_VALUE                                 2095 non-null   float64
#  29  Observation value                         0 non-null      float64
#  30  UNIT_MEASURE                              2095 non-null   object
#  31  Unit of measure                           2095 non-null   object
#  32  REPORTING_TYPE                            2095 non-null   object
#  33  Reporting type                            2095 non-null   object
#  34  NATURE                                    2095 non-null   object
#  35  Nature                                    2095 non-null   object
#  36  DATA_SOURCE                               2095 non-null   object
#  37  Data source                               0 non-null      float64
#  38  OBS_STATUS                                13 non-null     object
#  39  Observation Status                        13 non-null     object
#  40  OBS_COMMENT                               0 non-null      float64
#  41  Comment                                   0 non-null      float64
# dtypes: float64(6), int64(1), object(35)
# memory usage: 687.6+ KB
# None
#        STRUCTURE        STRUCTURE_ID  \
# count       2095                2095
# unique         1                   1
# top     DATAFLOW  SPC:DF_SDG_04(3.0)
# freq        2095                2095
# mean         NaN                 NaN
# std          NaN                 NaN
# min          NaN                 NaN
# 25%          NaN                 NaN
# 50%          NaN                 NaN
# 75%          NaN                 NaN
# max          NaN                 NaN
#
#                                            STRUCTURE_NAME ACTION  FREQ  \
# count                                                2095   2095  2095
# unique                                                  1      1     1
# top     Sustainable Development Goal 04 - Quality Educ...      I     A
# freq                                                 2095   2095  2095
# mean                                                  NaN    NaN   NaN
# std                                                   NaN    NaN   NaN
# min                                                   NaN    NaN   NaN
# 25%                                                   NaN    NaN   NaN
# 50%                                                   NaN    NaN   NaN
# 75%                                                   NaN    NaN   NaN
# max                                                   NaN    NaN   NaN
#
#        Frequency   INDICATOR               Indicator GEO_PICT  \
# count       2095        2095                    2095     2095
# unique         1          16                      16       17
# top       Annual  SE_GC_TCAQ  4.c.1 Trained teachers       CK
# freq        2095         595                     595      229
# mean         NaN         NaN                     NaN      NaN
# std          NaN         NaN                     NaN      NaN
# min          NaN         NaN                     NaN      NaN
# 25%          NaN         NaN                     NaN      NaN
# 50%          NaN         NaN                     NaN      NaN
# 75%          NaN         NaN                     NaN      NaN
# max          NaN         NaN                     NaN      NaN
#
#        Pacific Island Countries and territories  ... REPORTING_TYPE  \
# count                                      2095  ...           2095
# unique                                       17  ...              3
# top                                Cook Islands  ...              G
# freq                                        229  ...           1117
# mean                                        NaN  ...            NaN
# std                                         NaN  ...            NaN
# min                                         NaN  ...            NaN
# 25%                                         NaN  ...            NaN
# 50%                                         NaN  ...            NaN
# 75%                                         NaN  ...            NaN
# max                                         NaN  ...            NaN
#
#        Reporting type NATURE        Nature                     DATA_SOURCE  \
# count            2095   2095          2095                            2095
# unique              3      2             2                             172
# top            Global      C  Country Data  UNESCO Institute of Statistics
# freq             1117   2094          2094                             708
# mean              NaN    NaN           NaN                             NaN
# std               NaN    NaN           NaN                             NaN
# min               NaN    NaN           NaN                             NaN
# 25%               NaN    NaN           NaN                             NaN
# 50%               NaN    NaN           NaN                             NaN
# 75%               NaN    NaN           NaN                             NaN
# max               NaN    NaN           NaN                             NaN
#
#        Data source OBS_STATUS Observation Status OBS_COMMENT Comment
# count          0.0         13                 13         0.0     0.0
# unique         NaN          1                  1         NaN     NaN
# top            NaN          A       Normal value         NaN     NaN
# freq           NaN         13                 13         NaN     NaN
# mean           NaN        NaN                NaN         NaN     NaN
# std            NaN        NaN                NaN         NaN     NaN
# min            NaN        NaN                NaN         NaN     NaN
# 25%            NaN        NaN                NaN         NaN     NaN
# 50%            NaN        NaN                NaN         NaN     NaN
# 75%            NaN        NaN                NaN         NaN     NaN
# max            NaN        NaN                NaN         NaN     NaN
#
# [11 rows x 42 columns]
# Missing values: STRUCTURE                                      0
# STRUCTURE_ID                                   0
# STRUCTURE_NAME                                 0
# ACTION                                         0
# FREQ                                           0
# Frequency                                      0
# INDICATOR                                      0
# Indicator                                      0
# GEO_PICT                                       0
# Pacific Island Countries and territories       0
# SEX                                            0
# Sex                                            0
# AGE                                            0
# Age                                            0
# URBANIZATION                                   0
# Urbanization                                   0
# INCOME                                         0
# Income                                         0
# EDUCATION                                      0
# Education level                                0
# OCCUPATION                                     0
# Occupation                                     0
# COMPOSITE_BREAKDOWN                            0
# Composite breakdown                            0
# DISABILITY                                     0
# Disability                                     0
# TIME_PERIOD                                    0
# Time                                        2095
# OBS_VALUE                                      0
# Observation value                           2095
# UNIT_MEASURE                                   0
# Unit of measure                                0
# REPORTING_TYPE                                 0
# Reporting type                                 0
# NATURE                                         0
# Nature                                         0
# DATA_SOURCE                                    0
# Data source                                 2095
# OBS_STATUS                                  2082
# Observation Status                          2082
# OBS_COMMENT                                 2095
# Comment                                     2095
# dtype: int64

# %%
# Top countries by record count
top_locations = df['Location'].value_counts().head(10)
top_locations.plot(kind='barh', title='Top 10 Countries by Record Count')
plt.xlabel("Number of Records")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Top countries by record count
# ----> 2 top_locations = df['Location'].value_counts().head(10)
#       3 top_locations.plot(kind='barh', title='Top 10 Countries by Record Count')
#       4 plt.xlabel("Number of Records")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Location'

# %%
# Example trend: Out-of-school rate over time
subset = df[df['Indicator'].str.contains("out-of-school", case=False)]

# Check the actual column names in the DataFrame
# print(subset.columns)  # Uncomment this line to see all column names

# Assuming the year column might be named differently, like 'TIME' or 'Date'
# Replace 'TIME' with the actual column name for year in your DataFrame
sns.lineplot(data=subset, x='TIME', y='Value', hue='Location')
plt.title("Out-of-School Rate Over Time")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       2 subset = df[df['Indicator'].str.contains("out-of-school", case=False)]
#       4 # Check the actual column names in the DataFrame
#       5 # print(subset.columns)  # Uncomment this line to see all column names
#       6
#       7 # Assuming the year column might be named differently, like 'TIME' or 'Date'
#       8 # Replace 'TIME' with the actual column name for year in your DataFrame
# ----> 9 sns.lineplot(data=subset, x='TIME', y='Value', hue='Location')
#      10 plt.title("Out-of-School Rate Over Time")
#      11 plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)    210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\anaconda3\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\anaconda3\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\anaconda3\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `TIME` for `x`. An entry with this name does not appear in `data`.

# %%
# Pivot for clustering
pivot_df = df.pivot_table(index='Location', columns='Indicator', values='Value', aggfunc='mean')
pivot_df.fillna(0, inplace=True)

# Standardize
scaler = StandardScaler()
scaled_data = scaler.fit_transform(pivot_df)

# PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# Add results
pivot_df['Cluster'] = clusters
pivot_df['PCA1'] = pca_result[:, 0]
pivot_df['PCA2'] = pca_result[:, 1]

# Plot
sns.scatterplot(data=pivot_df, x='PCA1', y='PCA2', hue='Cluster', palette='Set2')
plt.title("KMeans Clustering of Countries (Education Indicators)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Pivot for clustering
# ----> 2 pivot_df = df.pivot_table(index='Location', columns='Indicator', values='Value', aggfunc='mean')
#       3 pivot_df.fillna(0, inplace=True)
#       5 # Standardize
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)   9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'Value'

# %%
# Silhouette Score
score = silhouette_score(scaled_data, clusters)
print(f"Silhouette Score: {score:.2f}")

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.05, random_state=42)
pivot_df['Anomaly'] = iso.fit_predict(scaled_data)

# Show anomalous countries
print("Anomalous Countries:")
print(pivot_df[pivot_df['Anomaly'] == -1].index.tolist())
